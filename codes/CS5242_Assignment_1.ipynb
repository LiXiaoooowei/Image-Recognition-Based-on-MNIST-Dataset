# %% [markdown]
# # Introduction
#
#
# **ASSIGNMENT DEADLINE: 4 MAR 2018 (SUN) 17:00PM**
#
# In this assignment we will be coding the building blocks for the convolutional neural network and putting them together to train a CNN on the MNIST dataset.
#
# **Attention: Only python3 will be allowed to use in this assignment. And we use `numpy` to store and caculate data and parameters. You do not need a GPU to for this assignment. CPU is enough. To run this Jupyter notebook, you need to install the depedent libraries in [requiremets.txt](requirements.txt) via pip (or pip3). Note: keras version should be >=2.1.2. Please do not run this whole file before you implement all the codes. Otherwise it will occur some error.**
#
# For each layer we will implement a forward and a backward function. The forward function will receive inputs and will return the outputs of this layer(loss layer will be a little different), like this:
#
# ```python
# def forward(self, inputs):
#   """ Receive inputs and return output"""
#   # Do some computations ...
#   z = # ... some intermediate value
#   # Do some more computations ...
#   outputs = # the outputs
#
#   return outputs
# ```
#
# The backward pass will receive upstream derivatives and inputs, and will return gradients with respect to the inputs. Gradients for weights or bias will be stored in parameters in this layer , like this:
#
# ```python
# def backward(self, in_grads, inputs):
#   """
#   Receive derivative of loss with respect to outputs,
#   and compute derivative with respect to inputs.
#   """
#   # Use values in cache to compute derivatives
#   out_grads = # Derivative of loss with respect to inputs
#   self.w_grad = # Derivative of loss with respect to self.weights
#   self.b_grad = # Derivative of loss with respect to self.bias
#
#   return out_grads
# ```
#
# After implementing a bunch of layers this way, we will be able to easily combine them to build classifiers with different architectures.
#
# This iPython notebook serves to:
#
# - explain the questions
# - explain the function APIs and implementation examples (like `ReLU`)
# - provide helper functions to piece functions together and check your code

# %% [markdown]
# # ReLU layer
# A convolution layer is usually followed by a non-linear activation function. We will provide the functions `forward` and `backward` of class `ReLU` in `layers.py` as an implementation example. Read through the function code and make sure you understand the derivation. Besides, we will explain the implementation of `ReLU` after `Convolution` using formula. You need to write down other layers' formulations in your reports.
#
# ## Forward Formulation
# Given input $x \in R^{B \times C \times H \times W}$ ($B$:batch size, $C$: number of channel, $H$: input height, $W$: input width),  output $y \in R^{B \times C \times H \times W}$ will be caculated like this:
#
# \begin{equation*}
# y=indicator(x) \times x
# \end{equation*}
#
# Here, $indicator(x)$ return the same size of input $x$, comparing $x$ with 0 element-wisely. If $x_{i,j,k,l} \geq 0$ return $z_{i,j,k,l}=1$. And the multiplication is also element-wise. If the input $x$ has only 2 dimensions, i.e. the batch dimension and the feature dimension, e.g. after the FC layer, the subscripts $j,k,l$ in the formula are merged into one $j$.
#
# ## Backward Formulation
# Given input $x \in R^{B \times C \times H \times W}$ ($B$:batch size, $C$: number of channel, $H$: input height, $W$: input width) and gradients to output of this layer $dy \in R^{B \times C \times H \times W}$, gradients to input $dx$ will be caculated like this:
#
# \begin{equation*}
# dx=indicator(x) \times dy
# \end{equation*}

# %% [markdown]
# # Covolution Layer
# In the file `layers.py`, the class `Convolution` will be initialized with `conv_params`, `initializer` and `name`, shown as below:
#
# ```python
#
# def __init__(self, conv_params, initializer=Guassian(), name='conv'):
#         super(Convolution, self).__init__(name=name)
#         self.trainable = True
#         self.kernel_h = conv_params['kernel_h'] # height of kernel
#         self.kernel_w = conv_params['kernel_w'] # width of kernel
#         self.pad = conv_params['pad']
#         self.stride = conv_params['stride']
#         self.in_channel = conv_params['in_channel']
#         self.out_channel = conv_params['out_channel']
#
#         self.weights = initializer.initialize((self.out_channel, self.in_channel, self.kernel_h, self.kernel_w))
#         self.bias = np.zeros((self.out_channel))
#
#         self.w_grad = np.zeros(self.weights.shape)
#         self.b_grad = np.zeros(self.bias.shape)
# ```
#
# `conv_params` is a dictionary, containing these parameters:
#
# - 'kernel_h': The height of kernel.
# - 'kernel_w': The width of kernel.
# - 'stride': The number of pixels between adjacent receptive fields in the horizontal and vertical directions.
# - 'pad': The number of pixels padded to the bottom, top, left and right of each feature map. **Here, `pad=2` means a 2-pixel border of padded with zeros. So the total number of zeros for horizontal (or vertical) direction is 2\*pad=4**.
# - 'in_channel': The number of input channels.
# - 'out_channel': The number of output channels.
#
# `initializer` is an instance of Initializer class (leave it out right now)

# %% [markdown]
# ## Forward
# In the file `layers.py`, implement the forward pass for a convolutional layer in the function `forward` of class `Convolution`.
#
# The input consists of N data points, each with C channels, height H and width W. We convolve each input with K different kernels, where each filter spans all C channels and has height HH and width WW.
#
# Input:
#
# - inputs: Input data of shape (N, C, H, W)
#
# **WARNING:** Please implement the matrix product method of convolution as shown in Lecture notes. The naive version of implementing a sliding window will be too slow when you try to train the whole CNN in later sections.
#
# You can test your implementation by restarting jupyter notebook kernel and running the following:

# %%
import numpy as np
from layers import Convolution
from utils.tools import rel_error

import keras
from keras import layers
from keras import models
from keras import optimizers
from keras import backend as K

import warnings
warnings.filterwarnings('ignore')

inputs = np.random.uniform(size=(10, 3, 30, 30))
params = { 'kernel_h': 5,
          'kernel_w': 5,
          'pad': 0,
          'stride': 2,
          'in_channel': inputs.shape[1],
          'out_channel': 64,
}
layer = Convolution(params)
out = layer.forward(inputs)

keras_model = keras.Sequential()
keras_layer = layers.Conv2D(filters=params['out_channel'],
                            kernel_size=(params['kernel_h'], params['kernel_w']),
                            strides=(params['stride'], params['stride']),
                            padding='valid',
                            data_format='channels_first',
                            input_shape=inputs.shape[1:])
keras_model.add(keras_layer)
sgd = optimizers.SGD(lr=0.01)
keras_model.compile(loss='mean_squared_error', optimizer='sgd')
weights = np.transpose(layer.weights, (2, 3, 1, 0))
keras_layer.set_weights([weights, layer.bias])
keras_out = keras_model.predict(inputs, batch_size=inputs.shape[0])
print('Relative error (<1e-6 will be fine): ', rel_error(out, keras_out))

## test
# inputs = np.tile(np.array([[[1, 2, 1, 2, 3, 4],[2, 2, 3, 1, 2, 0],[1, 1, 2, 1, 0, 1],[2, 1, 2, 1, 1, 3]],
#                           [[0, 2, 3, 2, 0, 1],[1, 0, 1, 1, 2, 0],[2, 0, 1, 1, 1, 1],[1, 1, 2, 1, 1, 2]]]), (3, 1, 1, 1))
# params = { 'kernel_h': 2,
#           'kernel_w': 2,
#           'pad': 0,
#           'stride': 2,
#           'in_channel': inputs.shape[1],
#           'out_channel': 5,
# }
# print(inputs.shape)
# layer = Convolution(params)
# out = layer.forward(inputs)
# print(out)
# Out:
# Using TensorFlow backend.
# Relative error (<1e-6 will be fine):  3.74585601692e-07

# %% [markdown]
# ## Backward
# Implement the backward pass for the convolution operation in the function `backward` of `Convolution` class in the file `layers.py`.
#
# When you are done, restart jupyter notebook and run the following to check your backward pass with a numeric gradient check.
#
# In gradient checking, to get an approximate gradient for a parameter, we vary that parameter by a small amount (while keeping rest of parameters constant) and note the difference in the network loss. Dividing the difference in network loss by the amount we varied the parameter gives us an approximation for the gradient. We repeat this process for all the other parameters to obtain our numerical gradient. Note that gradient checking is a slow process (2 forward propagations per parameter) and should only be used to check your backpropagation!
#
# More links on gradient checking:
#
# http://ufldl.stanford.edu/tutorial/supervised/DebuggingGradientChecking/
#
# https://www.coursera.org/learn/machine-learning/lecture/Y3s6r/gradient-checking

# %%
from layers import Convolution
import numpy as np
from utils.check_grads import check_grads_layer

batch = 10
conv_params={
    'kernel_h': 3,
    'kernel_w': 3,
    'pad': 0,
    'stride': 2,
    'in_channel': 3,
    'out_channel': 10
}
in_height = 10
in_width = 20
out_height = 1+(in_height+2*conv_params['pad']-conv_params['kernel_h'])//conv_params['stride']
out_width = 1+(in_width+2*conv_params['pad']-conv_params['kernel_w'])//conv_params['stride']
inputs = np.random.uniform(size=(batch, conv_params['in_channel'], in_height, in_width))
in_grads = np.random.uniform(size=(batch, conv_params['out_channel'], out_height, out_width))
conv = Convolution(conv_params)
check_grads_layer(conv, inputs, in_grads)
# Out:
# <1e-8 will be fine
# Gradients to inputs: 1.28571840154e-11
# Gradients to weights:  5.36571511833e-13
# Gradients to bias:  4.45215949226e-13

# %% [markdown]
# # Dropout Layer
# Dropout [1] is a technique for regularizing neural networks by randomly setting some features to zero during the forward pass. In this exercise you will implement a dropout layer and modify your fully-connected network to optionally use dropout.
#
# [1] Geoffrey E. Hinton et al, "Improving neural networks by preventing co-adaptation of feature detectors", arXiv 2012
#
# In the file `layers.py`, the class `FCLayer` will be initialized with `ratio`, `seed` and `name`, shown as below:
# ```python
# def __init__(self, ratio, name='dropout', seed=None):
#         super(Dropout, self).__init__(name=name)
#         self.ratio = ratio
#         self.mask = None
#         self.seed = seed
# ```
#
# - `ratio`: The probability of setting a neuron to zero
# - `seed`: Random seed to sample from inputs, so as to get mask. (default as None)

# %% [markdown]
# ## Forward
# In the file `layers.py`, implement the forward pass for dropout. Since dropout behaves differently during training and testing, make sure to implement the operation for both modes.  `p` refers to the probability of setting a neuron to zero. We will follow the Caffe convention where we multiply the outputs by `1/(1-p)` during training.

# %% [markdown]
# ## Backward
# In the file `layers.py`, implement the backward pass for dropout. After doing so, restart jupyter notebook and run the following cell to numerically gradient-check your implementation.

# %%
from layers import Dropout
import numpy as np
from utils.check_grads import check_grads_layer

ratio = 0.1
height = 10
width = 20
channel = 10
batch = 10 # Note that this batch value if specified by YOU. Pls confirm with teaching team.
np.random.seed(1234)
inputs = np.random.uniform(size=(batch, channel, height, width))
in_grads = np.random.uniform(size=(batch, channel, height, width))
dropout = Dropout(ratio, seed=1234)
dropout.set_mode(True)
check_grads_layer(dropout, inputs, in_grads)
# Out:
# <1e-8 will be fine
# Gradients to inputs: 3.53740988945e-12

# %% [markdown]
# # Pooling Layer
# In the file `layers.py`, the class `Pooling` will be initialized with `pool_params`, and `name`, shown as below:
# ```python
# def __init__(self, pool_params, name='pooling'):
#         super(Pooling, self).__init__(name=name)
#         self.pool_type = pool_params['pool_type']
#         self.pool_height = pool_params['pool_height']
#         self.pool_width = pool_params['pool_width']
#         self.stride = pool_params['stride']
#         self.pad = pool_params['pad']
# ```
#
# `pool_params` is a dictionary, containing these parameters:
#
# - 'pool_type': The type of pooling, 'max' or 'avg'
# - 'pool_h': The height of pooling kernel.
# - 'pool_w': The width of pooling kernel.
# - 'stride': The number of pixels between adjacent receptive fields in the horizontal and vertical directions.
# - 'pad': The number of pixels that will be used to zero-pad the input in each x-y direction. **Here, `pad=2` means a 2-pixel border of padding with zeros**.

# %% [markdown]
# ## Forward
# Implement the forward pass for the pooling operation in the function `forward` of class `Pooling` in the file `layers.py`.
#
# You can test your implementation by restarting jupyter notebook kernel and running the following:

# %%
import numpy as np
from layers import Pooling
from utils.tools import rel_error

import keras
from keras import layers
from keras import models
from keras import optimizers
from keras import backend as K

import warnings
warnings.filterwarnings('ignore')

# # test
# inputs = np.tile(np.array([[[1, 2, 1, 2, 3, 4],[2, 2, 3, 1, 2, 0],[1, 1, 2, 1, 0, 1],[2, 1, 2, 1, 1, 3]],
#                           [[0, 2, 3, 2, 0, 1],[1, 0, 1, 1, 2, 0],[2, 0, 1, 1, 1, 1],[1, 1, 2, 1, 1, 2]]]), (3, 1, 1, 1))
# params = { 'pool_type': 'avg',
#           'pool_height': 2,
#           'pad': 0,
#           'stride': 2,
#           'pool_width': 2,
# }
# layer = Pooling(params)
# out = layer.forward(inputs)
# ##
inputs = np.random.uniform(size=(10, 3, 30, 30))
params = { 'pool_type': 'max',
           'pool_height': 5,
           'pool_width': 5,
           'pad': 0,
           'stride': 2,
}
layer = Pooling(params)
out = layer.forward(inputs)

keras_model = keras.Sequential()
keras_layer = layers.MaxPooling2D(pool_size=(params['pool_height'], params['pool_width']),
                                 strides=params['stride'],
                                 padding='valid',
                                 data_format='channels_first',
                                 input_shape=inputs.shape[1:])
keras_model.add(keras_layer)
sgd = optimizers.SGD(lr=0.01)
keras_model.compile(loss='mean_squared_error', optimizer='sgd')
keras_out = keras_model.predict(inputs, batch_size=inputs.shape[0])
print('Relative error (<1e-6 will be fine): ', rel_error(out, keras_out))

# self written
inputs = np.random.uniform(size=(10, 3, 30, 30))
params = { 'pool_type': 'avg',
           'pool_height': 5,
           'pool_width': 5,
           'pad': 0,
           'stride': 2,
}
layer = Pooling(params)
out = layer.forward(inputs)

keras_model = keras.Sequential()
keras_layer = layers.AveragePooling2D(pool_size=(params['pool_height'], params['pool_width']),
                                 strides=params['stride'],
                                 padding='valid',
                                 data_format='channels_first',
                                 input_shape=inputs.shape[1:])
keras_model.add(keras_layer)
sgd = optimizers.SGD(lr=0.01)
keras_model.compile(loss='mean_squared_error', optimizer='sgd')
keras_out = keras_model.predict(inputs, batch_size=inputs.shape[0])
print('Relative error (<1e-6 will be fine): ', rel_error(out, keras_out))
# Out:
# Relative error (<1e-6 will be fine):  7.93255742904e-09
# Relative error (<1e-6 will be fine):  3.20741105627e-08

# %% [markdown]
# ## Backward
# Implement the backward pass for the max-pooling operation in the function `backward` of class `Pooling` in the file `layers.py`.
#
# Please make sure you have implemented both ’max’ and ’avg’ pooing in your codes. And then test the gradients by yourself.

# %%
import numpy as np
from layers import Pooling
from utils.check_grads import check_grads_layer

batch, channel_in, in_height, in_width = 10, 3, 30, 30
maxpool_params = { 
           'pool_type': 'max',
           'pool_height': 5,
           'pool_width': 5,
           'pad': 0,
           'stride': 2,
}
avgpool_params = { 
           'pool_type': 'avg',
           'pool_height': 5,
           'pool_width': 5,
           'pad': 0,
           'stride': 2,
}
out_height = 1 + (in_height + 2 * maxpool_params['pad'] - maxpool_params['pool_height']) // maxpool_params['stride']
out_width = 1 + (in_width + 2 * maxpool_params['pad'] - maxpool_params['pool_width']) // maxpool_params['stride']
inputs = np.random.uniform(size = (batch, channel_in, in_height, in_width))
in_grads = np.random.uniform(size = (batch, channel_in, out_height, out_width))

layer_maxpool = Pooling(maxpool_params)
check_grads_layer(layer_maxpool, inputs, in_grads)

layer_avgpool = Pooling(avgpool_params)
check_grads_layer(layer_avgpool, inputs, in_grads)
# Out:
# <1e-8 will be fine
# Gradients to inputs: 4.55111235013e-12
# <1e-8 will be fine
# Gradients to inputs: 2.42916337435e-11

# %% [markdown]
# # FC Layer
#
# FC layer (short for fully connected layer) is also called linear layer or dense layer.
#
# In the file `layers.py`, the class `FCLayer` will be initialized with `in_features`, `out_features`, and `name`, shown as below:
# ```python
# def __init__(self, in_features, out_features, name='fclayer', initializer=Guassian()):
#         super(FCLayer, self).__init__(name=name)
#         self.trainable = True
#         self.weights = initializer.initialize((in_features, out_features))
#         self.bias = initializer.initialize(out_features)
#
#         self.w_grad = np.zeros(self.weights.shape)
#         self.b_grad = np.zeros(self.bias.shape)
# ```
#
# - `in_features`: The number of inputs features
# - `out_features`: The numbet of required outputs features

# %% [markdown]
# ## Forward
# Implement the forward pass for the pooling operation in the function `forward` of class `FCLayer` in the file `layers.py`.
#
# You can test your implementation by restarting jupyter notebook kernel and running the following:

# %%
import numpy as np
from layers import FCLayer
from utils.tools import rel_error

import keras
from keras import layers
from keras import models
from keras import optimizers
from keras import backend as K

import warnings
warnings.filterwarnings('ignore')

inputs = np.random.uniform(size=(10, 20))

layer = FCLayer(in_features=inputs.shape[1], out_features=100)
out = layer.forward(inputs)

keras_model = keras.Sequential()
keras_layer = layers.Dense(100, input_shape=inputs.shape[1:], use_bias=True, kernel_initializer='random_normal', bias_initializer='zeros')
# print (len(keras_layer.get_weights()))
keras_model.add(keras_layer)
sgd = optimizers.SGD(lr=0.01)
keras_model.compile(loss='mean_squared_error', optimizer='sgd')
keras_layer.set_weights([layer.weights, layer.bias])
keras_out = keras_model.predict(inputs, batch_size=inputs.shape[0])
print('Relative error (<1e-6 will be fine): ', rel_error(out, keras_out))
# Out:
# Relative error (<1e-6 will be fine):  1.60849396343e-07

# %% [markdown]
# ## Backward
# Implement the backward pass for the max-pooling operation in the function `backward` of class `FCLayer` in the file `layers.py`. Please test the gradients by yourself.

# %%
import numpy as np
from layers import FCLayer
from utils.check_grads import check_grads_layer

batch = 10
feature_in = 20
feature_out = 100
inputs = np.random.uniform(size = (batch, feature_in))

layer = FCLayer(in_features = inputs.shape[1], out_features = feature_out)
in_grads = np.random.uniform(size = (batch, feature_out))
check_grads_layer(layer, inputs, in_grads)
# Out:
# <1e-8 will be fine
# Gradients to inputs: 1.32300784713e-11
# Gradients to weights:  1.06680708891e-12
# Gradients to bias:  7.77221605936e-13

# %% [markdown]
# # SoftmaxCrossEntropy Loss
# We write Softmax and CrossEntropy together because it can avoid some numeric overflow problem.In the file `loss.py`, the class `SoftmaxCrossEntropy` will be initialized with `num_class`,  shown as below:
# ```python
# def __init__(self, num_class):
#         super(SoftmaxCrossEntropy, self).__init__()
#         self.num_class = num_class
# ```
#
# `num_class`: The number of category

# %% [markdown]
# ## Forward
# Implement the forward pass for the pooling operation in the function `forward` of class `FCLayer` in the file `layers.py`.
#
# You can test your implementation by restarting jupyter notebook kernel and running the following:

# %%
import numpy as np
from loss import SoftmaxCrossEntropy
from utils.tools import rel_error

import keras
from keras import layers
from keras import models
from keras import optimizers
from keras import backend as K

import warnings
warnings.filterwarnings('ignore')

batch = 10
num_class = 10
inputs = np.random.uniform(size=(batch, num_class))
targets = np.random.randint(num_class, size=batch)

loss = SoftmaxCrossEntropy(num_class)
out, _ = loss.forward(inputs, targets)

keras_inputs = K.softmax(inputs)
keras_targets = np.zeros(inputs.shape, dtype='int')
for i in range(batch):
        keras_targets[i, targets[i]] = 1
keras_out = K.mean(K.categorical_crossentropy(keras_targets, keras_inputs, from_logits=False))
print('Relative error (<1e-6 will be fine): ', rel_error(out, K.eval(keras_out)))
# Out:
# Relative error (<1e-6 will be fine):  9.54519963305e-17

# %% [markdown]
# ## Backward
# In the file `loss.py`, implement the backward pass for `SodtmaxCrossEntropy`. Please test the gradients by yourself.

# %%
import numpy as np
from loss import SoftmaxCrossEntropy
from utils.check_grads import check_grads_loss

batch = 10
num_class = 10
inputs = np.random.uniform(size=(batch, num_class))
targets = np.random.randint(num_class, size=batch)

layer = SoftmaxCrossEntropy(num_class)

check_grads_loss(layer, inputs, targets)
# Out:
# <1e-8 will be fine
# inputs: 4.41878955409e-10

# %% [markdown]
# # Optimizer
# In the file `optimizers.py`, there are 4 types of optimizer (`SGD`, `Adam`, `RMSprop` and `Adagrad`). You only need to implement the `update` function of `SGD`(mini-batch SGD with momentum) and `Adam`. These two types of optimizers are initialized like this:
#
# ```python
# class SGD(Optimizer):
#     def __init__(self, lr=0.01, momentum=0, decay=0, sheduler_func = None):
#         super(SGD, self).__init__(lr)
#         self.momentum = momentum
#         self.moments = None
#         self.decay = decay
#         self.sheduler_func = sheduler_func
#
# class Adam(Optimizer):
#     def __init__(self, lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0, sheduler_func=None):
#         super(Adam, self).__init__(lr)
#         self.beta_1 = beta_1
#         self.beta_2 = beta_2
#         self.epsilon = epsilon
#         self.decay = decay
#         if not self.epsilon:
#             self.epsilon = 1e-8
#         self.moments = None
#         self.accumulators = None
#         self.sheduler_func = sheduler_func
# ```
#
# For Both optimizers:
# - `lr`: The initial learning rate.
# - `decay`: The learning rate decay ratio
# - `sheduler_func`: Function to change learning rate with respect to iterations
#
# For `SGD`:
# - `momentum`: The ratio of moments
#
#
# For `Adam`:
# More details can be seen in reference.
#
# **For you reference:**
# http://cs231n.github.io/neural-networks-3/#update

# %% [markdown]
# # Train the net on full MNIST data
# By training the `MNISTNet` for one epoch, you should achieve about 90% on the validation and test set. You may have to wait about 5 minutes for training to be completed.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from applications import MNISTNet
from loss import SoftmaxCrossEntropy, L2
from optimizers import Adam, RMSprop, SGD, Adagrad
from utils.datsets import MNIST
import numpy as np

mnist = MNIST()
mnist.load()
print(mnist.x_train.shape)
idx = np.random.randint(mnist.num_train, size=4)
idx = np.array([mnist.num_train - 1, mnist.num_train - 2, mnist.num_train - 3, mnist.num_train - 4])
print('\nFour examples of training images:')
img = mnist.x_train[idx][:,0,:,:]

plt.figure(1, figsize=(18, 18))
plt.subplot(1, 4, 1)
plt.imshow(img[0])
plt.subplot(1, 4, 2)
plt.imshow(img[1])
plt.subplot(1, 4, 3)
plt.imshow(img[2])
plt.subplot(1, 4, 4)
plt.imshow(img[3])
# Out:
# shape is (60000, 28, 28)
# Number of training images:  162000
# Number of validation images:  18000
# Number of testing images:  10000
# (162000, 1, 28, 28)
#
# Four examples of training images:

# %%
model = MNISTNet()
loss = SoftmaxCrossEntropy(num_class=10)

# define your learning rate sheduler
def func(lr, iteration):
    if iteration % 1000 ==0:
        return lr*0.5
    else:
        return lr

adam = Adam(lr=0.001, decay=0,  sheduler_func = func)
l2 = L2(w=0.001) # L2 regularization with lambda=0.001
model.compile(optimizer=adam, loss=loss, regularization=l2)
train_results, val_results, test_results = model.train(
    mnist, 
    train_batch=30, val_batch=1000, test_batch=1000, 
    epochs=2, 
    val_intervals=100, test_intervals=300, print_intervals=100)
# Out:
# Epoch 0:
# Test accuracy=0.10270, loss=2.30259
# Validation accuracy: 0.10744, loss: 2.30259
# Iteration 0:	accuracy=0.03333, loss=2.30259, regularization loss= 0.02029015235705403
# Validation accuracy: 0.57278, loss: 1.54061
# Iteration 100:	accuracy=0.66667, loss=1.03500, regularization loss= 0.05088536760835027
# Validation accuracy: 0.66117, loss: 1.25703
# Iteration 200:	accuracy=0.80000, loss=1.05152, regularization loss= 0.08397928017558502
# Test accuracy=0.94580, loss=0.20139
# Validation accuracy: 0.70644, loss: 1.04097
# Iteration 300:	accuracy=0.96667, loss=0.20816, regularization loss= 0.09709571041904368
# Validation accuracy: 0.71361, loss: 1.01014
# Iteration 400:	accuracy=0.83333, loss=0.61568, regularization loss= 0.10584125356840668
# Validation accuracy: 0.72239, loss: 0.98871
# Iteration 500:	accuracy=0.90000, loss=0.35967, regularization loss= 0.12100929609966744
# Test accuracy=0.96320, loss=0.12499
# Validation accuracy: 0.73794, loss: 0.89513
# Iteration 600:	accuracy=0.93333, loss=0.19446, regularization loss= 0.12988751689391284
# Validation accuracy: 0.73378, loss: 0.93601
# Iteration 700:	accuracy=0.90000, loss=0.41853, regularization loss= 0.13505449390037758
# Validation accuracy: 0.73328, loss: 1.10798
# Iteration 800:	accuracy=0.86667, loss=0.53462, regularization loss= 0.1444237761262261
# Test accuracy=0.93380, loss=0.20194
# Validation accuracy: 0.72033, loss: 1.11791
# Iteration 900:	accuracy=0.83333, loss=0.72837, regularization loss= 0.15080110473639732
# Validation accuracy: 0.74611, loss: 0.82946
# Iteration 1000:	accuracy=0.86667, loss=0.27204, regularization loss= 0.15429734036621687
# Validation accuracy: 0.77750, loss: 0.84362
# Iteration 1100:	accuracy=0.90000, loss=0.29042, regularization loss= 0.15668686610907415
# Test accuracy=0.95200, loss=0.14456
# Validation accuracy: 0.74583, loss: 0.93114
# Iteration 1200:	accuracy=0.90000, loss=0.34397, regularization loss= 0.15798489839693244
# Validation accuracy: 0.76744, loss: 0.89279
# Iteration 1300:	accuracy=0.93333, loss=0.24559, regularization loss= 0.16467883866062588
# Validation accuracy: 0.78344, loss: 0.79181
# Iteration 1400:	accuracy=0.96667, loss=0.15504, regularization loss= 0.1653314279593069
# Test accuracy=0.97440, loss=0.09221
# Validation accuracy: 0.78983, loss: 0.75761
# Iteration 1500:	accuracy=0.90000, loss=0.39474, regularization loss= 0.16947407221833818
# Validation accuracy: 0.78161, loss: 0.79176
# Iteration 1600:	accuracy=0.90000, loss=0.21795, regularization loss= 0.17617340164397455
# Validation accuracy: 0.79167, loss: 0.71778
# Iteration 1700:	accuracy=0.96667, loss=0.10499, regularization loss= 0.1841028668334007
# Test accuracy=0.97020, loss=0.09389
# Validation accuracy: 0.77978, loss: 0.79610
# Iteration 1800:	accuracy=0.93333, loss=0.28924, regularization loss= 0.18674194781879988
# Validation accuracy: 0.77678, loss: 0.79913
# Iteration 1900:	accuracy=0.93333, loss=0.30044, regularization loss= 0.189498206449203
# Validation accuracy: 0.80239, loss: 0.68892
# Iteration 2000:	accuracy=0.86667, loss=0.37795, regularization loss= 0.19804082663967426
# Test accuracy=0.98030, loss=0.07133
# Validation accuracy: 0.80172, loss: 0.69785
# Iteration 2100:	accuracy=0.93333, loss=0.27488, regularization loss= 0.19948708545310964
# Validation accuracy: 0.80756, loss: 0.68852
# Iteration 2200:	accuracy=0.93333, loss=0.26588, regularization loss= 0.201640839789837
# Validation accuracy: 0.81244, loss: 0.66174
# Iteration 2300:	accuracy=1.00000, loss=0.05922, regularization loss= 0.20475565590548842
# Test accuracy=0.97900, loss=0.07082
# Validation accuracy: 0.81156, loss: 0.68421
# Iteration 2400:	accuracy=0.86667, loss=0.24908, regularization loss= 0.20833980258037263
# Validation accuracy: 0.80600, loss: 0.66847
# Iteration 2500:	accuracy=0.93333, loss=0.29585, regularization loss= 0.2093126726824819
# Validation accuracy: 0.80728, loss: 0.69366
# Iteration 2600:	accuracy=0.90000, loss=0.38059, regularization loss= 0.21314452786280236
# Test accuracy=0.98010, loss=0.07270
# Validation accuracy: 0.81089, loss: 0.64660
# Iteration 2700:	accuracy=0.90000, loss=0.24034, regularization loss= 0.21705786333773586
# Validation accuracy: 0.80833, loss: 0.67387
# Iteration 2800:	accuracy=0.83333, loss=0.42054, regularization loss= 0.22100015983655494
# Validation accuracy: 0.80356, loss: 0.66979
# Iteration 2900:	accuracy=1.00000, loss=0.05278, regularization loss= 0.22300020543678115
# Test accuracy=0.97660, loss=0.07844
# Validation accuracy: 0.80022, loss: 0.74031
# Iteration 3000:	accuracy=0.93333, loss=0.16820, regularization loss= 0.2268641901517608
# Validation accuracy: 0.81756, loss: 0.65385
# Iteration 3100:	accuracy=0.86667, loss=0.72969, regularization loss= 0.22852470276346656
# Validation accuracy: 0.81428, loss: 0.68065
# Iteration 3200:	accuracy=0.93333, loss=0.22515, regularization loss= 0.2305560631215467
# Test accuracy=0.98180, loss=0.06400
# Validation accuracy: 0.82072, loss: 0.64772
# Iteration 3300:	accuracy=0.90000, loss=0.35509, regularization loss= 0.23277190986968516
# Validation accuracy: 0.81589, loss: 0.67249
# Iteration 3400:	accuracy=0.90000, loss=0.24310, regularization loss= 0.23479006387761914
# Validation accuracy: 0.82283, loss: 0.63086
# Iteration 3500:	accuracy=0.86667, loss=0.32816, regularization loss= 0.23668539005882572
# Test accuracy=0.98310, loss=0.06414
# Validation accuracy: 0.82300, loss: 0.62417
# Iteration 3600:	accuracy=0.96667, loss=0.25197, regularization loss= 0.23863627569796972
# Validation accuracy: 0.82311, loss: 0.62304
# Iteration 3700:	accuracy=0.93333, loss=0.22816, regularization loss= 0.2412093670082461
# Validation accuracy: 0.81739, loss: 0.64425
# Iteration 3800:	accuracy=1.00000, loss=0.04332, regularization loss= 0.24320332241492157
# Test accuracy=0.98260, loss=0.06024
# Validation accuracy: 0.82244, loss: 0.64007
# Iteration 3900:	accuracy=1.00000, loss=0.05364, regularization loss= 0.2450317551978438
# Validation accuracy: 0.82289, loss: 0.61545
# Iteration 4000:	accuracy=0.86667, loss=0.33289, regularization loss= 0.24794540448360994
# Validation accuracy: 0.82628, loss: 0.61353
# Iteration 4100:	accuracy=0.96667, loss=0.13781, regularization loss= 0.24970212185977006
# Test accuracy=0.98280, loss=0.06218
# Validation accuracy: 0.82750, loss: 0.60301
# Iteration 4200:	accuracy=1.00000, loss=0.08838, regularization loss= 0.2505886811113389
# Validation accuracy: 0.82472, loss: 0.62007
# Iteration 4300:	accuracy=0.93333, loss=0.38941, regularization loss= 0.25202605540745565
# Validation accuracy: 0.82606, loss: 0.60705
# Iteration 4400:	accuracy=0.93333, loss=0.26022, regularization loss= 0.25262871191483
# Test accuracy=0.98270, loss=0.05923
# Validation accuracy: 0.82978, loss: 0.61181
# Iteration 4500:	accuracy=0.93333, loss=0.38168, regularization loss= 0.2538393846101073
# Validation accuracy: 0.82606, loss: 0.62484
# Iteration 4600:	accuracy=0.93333, loss=0.15549, regularization loss= 0.2551268528035896
# Validation accuracy: 0.82772, loss: 0.60554
# Iteration 4700:	accuracy=1.00000, loss=0.09765, regularization loss= 0.2563552005945551
# Test accuracy=0.98280, loss=0.05941
# Validation accuracy: 0.82689, loss: 0.60001
# Iteration 4800:	accuracy=0.93333, loss=0.11877, regularization loss= 0.2580578503220262
# Validation accuracy: 0.82800, loss: 0.61427
# Iteration 4900:	accuracy=0.96667, loss=0.06665, regularization loss= 0.2590989530361788
# Validation accuracy: 0.83000, loss: 0.60479
# Iteration 5000:	accuracy=0.90000, loss=0.38965, regularization loss= 0.26044123419969173
# Test accuracy=0.98250, loss=0.05875
# Validation accuracy: 0.83083, loss: 0.60331
# Iteration 5100:	accuracy=0.80000, loss=0.60964, regularization loss= 0.26074049014626777
# Validation accuracy: 0.82856, loss: 0.59849
# Iteration 5200:	accuracy=0.93333, loss=0.30306, regularization loss= 0.2613848539880572
# Validation accuracy: 0.82767, loss: 0.59639
# Iteration 5300:	accuracy=0.90000, loss=0.26094, regularization loss= 0.2621297334050803
# Epoch 1:
# Test accuracy=0.98370, loss=0.05829
# Validation accuracy: 0.82950, loss: 0.59651
# Iteration 0:	accuracy=1.00000, loss=0.09074, regularization loss= 0.2626057644069421
# Validation accuracy: 0.82911, loss: 0.59047
# Iteration 100:	accuracy=0.96667, loss=0.08974, regularization loss= 0.26337185558164355
# Validation accuracy: 0.83156, loss: 0.59023
# Iteration 200:	accuracy=0.96667, loss=0.12271, regularization loss= 0.26419277649276474
# Test accuracy=0.98380, loss=0.05852
# Validation accuracy: 0.83017, loss: 0.59198
# Iteration 300:	accuracy=0.93333, loss=0.39345, regularization loss= 0.26477658271313664
# Validation accuracy: 0.82911, loss: 0.59182
# Iteration 400:	accuracy=0.90000, loss=0.32366, regularization loss= 0.2656054037644636
# Validation accuracy: 0.83256, loss: 0.58445
# Iteration 500:	accuracy=0.93333, loss=0.39423, regularization loss= 0.26608018546345413
# Test accuracy=0.98290, loss=0.05947
# Validation accuracy: 0.83394, loss: 0.58148
# Iteration 600:	accuracy=0.96667, loss=0.06137, regularization loss= 0.26678745998274866
# Validation accuracy: 0.83294, loss: 0.58213
# Iteration 700:	accuracy=0.96667, loss=0.15160, regularization loss= 0.2672221484201589
# Validation accuracy: 0.83200, loss: 0.58862
# Iteration 800:	accuracy=0.93333, loss=0.20569, regularization loss= 0.2676603335196458
# Test accuracy=0.98330, loss=0.05829
# Validation accuracy: 0.83294, loss: 0.58409
# Iteration 900:	accuracy=0.90000, loss=0.37706, regularization loss= 0.2679065231930329
# Validation accuracy: 0.83222, loss: 0.58611
# Iteration 1000:	accuracy=0.93333, loss=0.14623, regularization loss= 0.268250637236174
# Validation accuracy: 0.83294, loss: 0.58530
# Iteration 1100:	accuracy=0.93333, loss=0.11360, regularization loss= 0.2686022937333826
# Test accuracy=0.98360, loss=0.05812
# Validation accuracy: 0.83417, loss: 0.58055
# Iteration 1200:	accuracy=0.83333, loss=0.59047, regularization loss= 0.26907568827211015
# Validation accuracy: 0.83022, loss: 0.58825
# Iteration 1300:	accuracy=0.96667, loss=0.15313, regularization loss= 0.26940791579025897
# Validation accuracy: 0.83378, loss: 0.57686
# Iteration 1400:	accuracy=0.90000, loss=0.37869, regularization loss= 0.2695932413065394
# Test accuracy=0.98430, loss=0.05813
# Validation accuracy: 0.83394, loss: 0.57629
# Iteration 1500:	accuracy=0.86667, loss=0.22219, regularization loss= 0.2700165910548731
# Validation accuracy: 0.83344, loss: 0.57778
# Iteration 1600:	accuracy=0.83333, loss=0.63331, regularization loss= 0.2703765391263739
# Validation accuracy: 0.83456, loss: 0.57670
# Iteration 1700:	accuracy=0.90000, loss=0.22062, regularization loss= 0.2705563083472233
# Test accuracy=0.98430, loss=0.05785
# Validation accuracy: 0.83389, loss: 0.57740
# Iteration 1800:	accuracy=0.96667, loss=0.06853, regularization loss= 0.270763516160083
# Validation accuracy: 0.83428, loss: 0.57679
# Iteration 1900:	accuracy=0.93333, loss=0.25249, regularization loss= 0.2710106324250386
# Validation accuracy: 0.83389, loss: 0.57797
# Iteration 2000:	accuracy=0.96667, loss=0.06251, regularization loss= 0.2712111285408
# Test accuracy=0.98460, loss=0.05778
# Validation accuracy: 0.83244, loss: 0.57952
# Iteration 2100:	accuracy=0.96667, loss=0.06779, regularization loss= 0.2713647513381026
# Validation accuracy: 0.83322, loss: 0.57965
# Iteration 2200:	accuracy=0.93333, loss=0.21468, regularization loss= 0.2715491806901455
# Validation accuracy: 0.83389, loss: 0.57809
# Iteration 2300:	accuracy=0.90000, loss=0.32073, regularization loss= 0.2717463491367747
# Test accuracy=0.98380, loss=0.05832
# Validation accuracy: 0.83411, loss: 0.57759
# Iteration 2400:	accuracy=0.96667, loss=0.09429, regularization loss= 0.27191658310161404
# Validation accuracy: 0.83289, loss: 0.58413
# Iteration 2500:	accuracy=0.96667, loss=0.16239, regularization loss= 0.2720969616920196
# Validation accuracy: 0.83350, loss: 0.58545
# Iteration 2600:	accuracy=0.93333, loss=0.21242, regularization loss= 0.27228412424525383
# Test accuracy=0.98450, loss=0.05692
# Validation accuracy: 0.83350, loss: 0.58174
# Iteration 2700:	accuracy=0.90000, loss=0.24780, regularization loss= 0.27235585554450403
# Validation accuracy: 0.83361, loss: 0.58045
# Iteration 2800:	accuracy=0.96667, loss=0.11137, regularization loss= 0.2724449789914203
# Validation accuracy: 0.83378, loss: 0.57980
# Iteration 2900:	accuracy=1.00000, loss=0.05876, regularization loss= 0.2725307269945183
# Test accuracy=0.98430, loss=0.05691
# Validation accuracy: 0.83422, loss: 0.58116
# Iteration 3000:	accuracy=0.96667, loss=0.18579, regularization loss= 0.2726294614097634
# Validation accuracy: 0.83433, loss: 0.57932
# Iteration 3100:	accuracy=0.93333, loss=0.34285, regularization loss= 0.2727005755612111
# Validation accuracy: 0.83389, loss: 0.57927
# Iteration 3200:	accuracy=0.96667, loss=0.20172, regularization loss= 0.2727800533153978
# Test accuracy=0.98480, loss=0.05692
# Validation accuracy: 0.83367, loss: 0.57937
# Iteration 3300:	accuracy=0.90000, loss=0.39440, regularization loss= 0.27284651266775317
# Validation accuracy: 0.83411, loss: 0.57856
# Iteration 3400:	accuracy=1.00000, loss=0.01137, regularization loss= 0.27292966807429087
# Validation accuracy: 0.83394, loss: 0.58103
# Iteration 3500:	accuracy=0.93333, loss=0.14762, regularization loss= 0.2730282236236666
# Test accuracy=0.98470, loss=0.05683
# Validation accuracy: 0.83372, loss: 0.57966
# Iteration 3600:	accuracy=0.93333, loss=0.20857, regularization loss= 0.2731043844172443
# Validation accuracy: 0.83433, loss: 0.57869
# Iteration 3700:	accuracy=0.93333, loss=0.14547, regularization loss= 0.27315183329967424
# Validation accuracy: 0.83444, loss: 0.57845
# Iteration 3800:	accuracy=0.96667, loss=0.10633, regularization loss= 0.2731770285879041
# Test accuracy=0.98450, loss=0.05688
# Validation accuracy: 0.83356, loss: 0.58020
# Iteration 3900:	accuracy=0.96667, loss=0.16379, regularization loss= 0.2732299832515851
# Validation accuracy: 0.83389, loss: 0.58041
# Iteration 4000:	accuracy=0.90000, loss=0.46999, regularization loss= 0.27327707925910055
# Validation accuracy: 0.83350, loss: 0.58112
# Iteration 4100:	accuracy=0.86667, loss=0.32015, regularization loss= 0.2733221065133533
# Test accuracy=0.98410, loss=0.05687
# Validation accuracy: 0.83361, loss: 0.57993
# Iteration 4200:	accuracy=1.00000, loss=0.01210, regularization loss= 0.27336251063485706
# Validation accuracy: 0.83394, loss: 0.58003
# Iteration 4300:	accuracy=0.96667, loss=0.12144, regularization loss= 0.27341678153272003
# Validation accuracy: 0.83372, loss: 0.57904
# Iteration 4400:	accuracy=0.96667, loss=0.08134, regularization loss= 0.2734518202668473
# Test accuracy=0.98400, loss=0.05694
# Validation accuracy: 0.83383, loss: 0.57922
# Iteration 4500:	accuracy=0.83333, loss=0.36134, regularization loss= 0.27350797658175463
# Validation accuracy: 0.83417, loss: 0.57837
# Iteration 4600:	accuracy=1.00000, loss=0.06101, regularization loss= 0.2735570188746937
# Validation accuracy: 0.83356, loss: 0.57880
# Iteration 4700:	accuracy=0.93333, loss=0.09931, regularization loss= 0.27357271135438493
# Test accuracy=0.98380, loss=0.05707
# Validation accuracy: 0.83361, loss: 0.57861
# Iteration 4800:	accuracy=0.96667, loss=0.08588, regularization loss= 0.2735943321650813
# Validation accuracy: 0.83422, loss: 0.57835
# Iteration 4900:	accuracy=0.96667, loss=0.10163, regularization loss= 0.2736193690142717
# Validation accuracy: 0.83350, loss: 0.57935
# Iteration 5000:	accuracy=0.90000, loss=0.42141, regularization loss= 0.2736421263482395
# Test accuracy=0.98390, loss=0.05691
# Validation accuracy: 0.83372, loss: 0.57914
# Iteration 5100:	accuracy=0.86667, loss=0.42931, regularization loss= 0.27366129108457793
# Validation accuracy: 0.83439, loss: 0.57798
# Iteration 5200:	accuracy=0.96667, loss=0.21212, regularization loss= 0.27368737923296804
# Validation accuracy: 0.83422, loss: 0.57828
# Iteration 5300:	accuracy=0.90000, loss=0.31129, regularization loss= 0.2737102250150389

# %%
plt.figure(2, figsize=(18, 8))
plt.subplot(2, 3, 1)
plt.title('Training loss')
plt.plot(train_results[:,0], train_results[:,1])
plt.subplot(2, 3, 4)
plt.title('Training accuracy')
plt.plot(train_results[:,0], train_results[:,2])
plt.subplot(2, 3, 2)
plt.title('Validation loss')
plt.plot(val_results[:,0], val_results[:,1])
plt.subplot(2, 3, 5)
plt.title('Validation accuracy')
plt.plot(val_results[:,0], val_results[:,2])
plt.subplot(2, 3, 3)
plt.title('Testing loss')
plt.plot(test_results[:,0], test_results[:, 1])
plt.subplot(2, 3, 6)
plt.title('Testing accuracy')
plt.plot(test_results[:, 0], test_results[:,2])

# %% [markdown]
# ## Change of learning rate
# If we change the initial learning rate from 0.001 to 0.1, the training process becomes unstable and the loss is out of control. Thus, you need to be careful when setting the initial learning rate.

# %%
model = MNISTNet()
loss = SoftmaxCrossEntropy(num_class=10)

# define your learning rate sheduler
def func(lr, iteration):
    if iteration % 1000 ==0:
        return lr*0.5
    else:
        return lr

adam = Adam(lr=0.01, decay=0,  sheduler_func = func)
l2 = L2(w=0.001) # L2 regularization with lambda=0.001
model.compile(optimizer=adam, loss=loss, regularization=l2)
train_results, val_results, test_results = model.train(
    mnist, 
    train_batch=30, val_batch=1000, test_batch=1000, 
    epochs=2, 
    val_intervals=100, test_intervals=300, print_intervals=100)
# Out:
# Epoch 0:
# Test accuracy=0.10150, loss=2.30258
# Validation accuracy: 0.09811, loss: 2.30259
# Iteration 0:	accuracy=0.13333, loss=2.30258, regularization loss= 0.020321542312818217
# Validation accuracy: 0.42917, loss: 2.63078
# Iteration 100:	accuracy=0.60000, loss=1.26854, regularization loss= 0.1564534126440085
# Validation accuracy: 0.53911, loss: 1.74402
# Iteration 200:	accuracy=0.63333, loss=1.11497, regularization loss= 0.17099334034622996
# Test accuracy=0.82410, loss=0.66585
# Validation accuracy: 0.57389, loss: 2.20306
# Iteration 300:	accuracy=0.83333, loss=0.60452, regularization loss= 0.16457491978742758
# Validation accuracy: 0.61967, loss: 1.47091
# Iteration 400:	accuracy=0.83333, loss=0.42683, regularization loss= 0.1588549556967322
# Validation accuracy: 0.65011, loss: 1.57590
# Iteration 500:	accuracy=0.86667, loss=0.40797, regularization loss= 0.16739171301415573
# Test accuracy=0.88250, loss=0.37107
# Validation accuracy: 0.64794, loss: 1.33752
# Iteration 600:	accuracy=0.80000, loss=0.44144, regularization loss= 0.16789408238512513
# Validation accuracy: 0.65706, loss: 1.77867
# Iteration 700:	accuracy=0.66667, loss=1.50523, regularization loss= 0.17122693617353268
# Validation accuracy: 0.67978, loss: 1.23459
# Iteration 800:	accuracy=0.83333, loss=0.65626, regularization loss= 0.16500816534729443
# Test accuracy=0.88080, loss=0.46059
# Validation accuracy: 0.64339, loss: 2.04555
# Iteration 900:	accuracy=0.83333, loss=0.88478, regularization loss= 0.15578945988506854
# Validation accuracy: 0.64950, loss: 1.72688
# Iteration 1000:	accuracy=0.86667, loss=0.49820, regularization loss= 0.15569906533366232
# Validation accuracy: 0.64033, loss: 1.40816
# Iteration 1100:	accuracy=0.83333, loss=0.40626, regularization loss= 0.1415758805562433
# Test accuracy=0.94760, loss=0.17176
# Validation accuracy: 0.71522, loss: 1.17264
# Iteration 1200:	accuracy=0.86667, loss=0.26889, regularization loss= 0.14663205600789933
# Validation accuracy: 0.70322, loss: 1.15045
# Iteration 1300:	accuracy=0.93333, loss=0.37480, regularization loss= 0.1445668451580216
# Validation accuracy: 0.71456, loss: 1.02314
# Iteration 1400:	accuracy=0.86667, loss=0.40434, regularization loss= 0.15676393336399913
# Test accuracy=0.95460, loss=0.14978
# Validation accuracy: 0.73850, loss: 1.07821
# Iteration 1500:	accuracy=0.80000, loss=0.95734, regularization loss= 0.16725834426978128
# Validation accuracy: 0.71750, loss: 1.06074
# Iteration 1600:	accuracy=0.76667, loss=0.63612, regularization loss= 0.16812293615413723
# Validation accuracy: 0.73183, loss: 1.01231
# Iteration 1700:	accuracy=0.93333, loss=0.32928, regularization loss= 0.1745803384760872
# Test accuracy=0.95500, loss=0.14476
# Validation accuracy: 0.74494, loss: 1.11048
# Iteration 1800:	accuracy=0.93333, loss=0.12978, regularization loss= 0.17180199958484213
# Validation accuracy: 0.75061, loss: 1.06912
# Iteration 1900:	accuracy=0.93333, loss=0.25221, regularization loss= 0.17555916736591928
# Validation accuracy: 0.67094, loss: 1.46068
# Iteration 2000:	accuracy=0.90000, loss=0.37933, regularization loss= 0.18325302670199653
# Test accuracy=0.95730, loss=0.13337
# Validation accuracy: 0.75594, loss: 0.97695
# Iteration 2100:	accuracy=0.90000, loss=0.32798, regularization loss= 0.1797154894751489
# Validation accuracy: 0.76189, loss: 0.87607
# Iteration 2200:	accuracy=0.90000, loss=0.25982, regularization loss= 0.17943965652330413
# Validation accuracy: 0.75656, loss: 0.87372
# Iteration 2300:	accuracy=1.00000, loss=0.07160, regularization loss= 0.18364557849143157
# Test accuracy=0.96350, loss=0.12089
# Validation accuracy: 0.75444, loss: 0.91387
# Iteration 2400:	accuracy=1.00000, loss=0.10165, regularization loss= 0.18567290731142938
# Validation accuracy: 0.75667, loss: 0.87115
# Iteration 2500:	accuracy=0.90000, loss=0.27934, regularization loss= 0.18836095604189185
# Validation accuracy: 0.75339, loss: 0.88526
# Iteration 2600:	accuracy=0.93333, loss=0.25080, regularization loss= 0.1948796089952334
# Test accuracy=0.96210, loss=0.12215
# Validation accuracy: 0.76389, loss: 0.92619
# Iteration 2700:	accuracy=0.96667, loss=0.09701, regularization loss= 0.20355750519465587
# Validation accuracy: 0.75506, loss: 0.99105
# Iteration 2800:	accuracy=0.86667, loss=0.55761, regularization loss= 0.2050949516123977
# Validation accuracy: 0.76683, loss: 0.85807
# Iteration 2900:	accuracy=0.96667, loss=0.06013, regularization loss= 0.20713229688353338
# Test accuracy=0.95260, loss=0.15036
# Validation accuracy: 0.74533, loss: 0.96080
# Iteration 3000:	accuracy=0.86667, loss=0.39382, regularization loss= 0.207464937962781
# Validation accuracy: 0.75589, loss: 0.93273
# Iteration 3100:	accuracy=0.86667, loss=0.48959, regularization loss= 0.21003428906338037
# Validation accuracy: 0.77067, loss: 0.91233
# Iteration 3200:	accuracy=0.86667, loss=0.38187, regularization loss= 0.21100055573233414
# Test accuracy=0.96880, loss=0.09855
# Validation accuracy: 0.76339, loss: 0.87407
# Iteration 3300:	accuracy=0.86667, loss=0.39759, regularization loss= 0.2135393463364621
# Validation accuracy: 0.75633, loss: 0.82218
# Iteration 3400:	accuracy=0.93333, loss=0.36694, regularization loss= 0.21905653599675592
# Validation accuracy: 0.77550, loss: 0.82040
# Iteration 3500:	accuracy=0.83333, loss=0.53609, regularization loss= 0.2222846735153256
# Test accuracy=0.97100, loss=0.09593
# Validation accuracy: 0.77917, loss: 0.80662
# Iteration 3600:	accuracy=0.93333, loss=0.25283, regularization loss= 0.22683546638307317
# Validation accuracy: 0.76739, loss: 0.92050
# Iteration 3700:	accuracy=0.86667, loss=0.46709, regularization loss= 0.22837018044504703
# Validation accuracy: 0.77583, loss: 0.80772
# Iteration 3800:	accuracy=0.96667, loss=0.09623, regularization loss= 0.23133448707411133
# Test accuracy=0.96600, loss=0.11225
# Validation accuracy: 0.77422, loss: 0.89334
# Iteration 3900:	accuracy=0.86667, loss=0.45735, regularization loss= 0.23341682159417648
# Validation accuracy: 0.76700, loss: 0.80626
# Iteration 4000:	accuracy=0.90000, loss=0.29197, regularization loss= 0.24029444285197551
# Validation accuracy: 0.78067, loss: 0.84004
# Iteration 4100:	accuracy=1.00000, loss=0.04872, regularization loss= 0.24247029074205148
# Test accuracy=0.97300, loss=0.08791
# Validation accuracy: 0.77794, loss: 0.81172
# Iteration 4200:	accuracy=0.90000, loss=0.36119, regularization loss= 0.24396218269606007
# Validation accuracy: 0.78889, loss: 0.79795
# Iteration 4300:	accuracy=0.90000, loss=0.26443, regularization loss= 0.2439326796882974
# Validation accuracy: 0.78794, loss: 0.78976
# Iteration 4400:	accuracy=0.96667, loss=0.18868, regularization loss= 0.2457166285419141
# Test accuracy=0.97410, loss=0.08348
# Validation accuracy: 0.79217, loss: 0.75713
# Iteration 4500:	accuracy=0.90000, loss=0.38415, regularization loss= 0.24844525544049528
# Validation accuracy: 0.78672, loss: 0.75844
# Iteration 4600:	accuracy=0.86667, loss=0.34394, regularization loss= 0.24998849872412668
# Validation accuracy: 0.79444, loss: 0.76088
# Iteration 4700:	accuracy=1.00000, loss=0.06306, regularization loss= 0.24992931832908616
# Test accuracy=0.97360, loss=0.08115
# Validation accuracy: 0.79133, loss: 0.77062
# Iteration 4800:	accuracy=0.93333, loss=0.16172, regularization loss= 0.2523676989142348
# Validation accuracy: 0.79400, loss: 0.77142
# Iteration 4900:	accuracy=0.93333, loss=0.28831, regularization loss= 0.25447603091493454
# Validation accuracy: 0.78989, loss: 0.79484
# Iteration 5000:	accuracy=0.83333, loss=0.29507, regularization loss= 0.2569250884099297
# Test accuracy=0.97360, loss=0.08460
# Validation accuracy: 0.79800, loss: 0.74474
# Iteration 5100:	accuracy=0.93333, loss=0.34721, regularization loss= 0.2576499186335133
# Validation accuracy: 0.79906, loss: 0.72780
# Iteration 5200:	accuracy=0.83333, loss=0.54973, regularization loss= 0.25786575240841836
# Validation accuracy: 0.79872, loss: 0.71535
# Iteration 5300:	accuracy=0.83333, loss=0.39072, regularization loss= 0.2590523305269541
# Epoch 1:
# Test accuracy=0.97520, loss=0.07955
# Validation accuracy: 0.80494, loss: 0.70888
# Iteration 0:	accuracy=0.93333, loss=0.17874, regularization loss= 0.2608075364231182
# Validation accuracy: 0.80500, loss: 0.71378
# Iteration 100:	accuracy=0.96667, loss=0.25088, regularization loss= 0.26231116909477387
# Validation accuracy: 0.79822, loss: 0.72724
# Iteration 200:	accuracy=0.96667, loss=0.32968, regularization loss= 0.26420380667090415
# Test accuracy=0.97640, loss=0.07711
# Validation accuracy: 0.80378, loss: 0.70867
# Iteration 300:	accuracy=0.96667, loss=0.29635, regularization loss= 0.2657269541630203
# Validation accuracy: 0.80422, loss: 0.70409
# Iteration 400:	accuracy=0.96667, loss=0.11711, regularization loss= 0.26689520659496996
# Validation accuracy: 0.80472, loss: 0.69953
# Iteration 500:	accuracy=1.00000, loss=0.03978, regularization loss= 0.26917963115826116
# Test accuracy=0.97700, loss=0.07408
# Validation accuracy: 0.80461, loss: 0.72244
# Iteration 600:	accuracy=0.90000, loss=0.25926, regularization loss= 0.2705589178957956
# Validation accuracy: 0.80294, loss: 0.73626
# Iteration 700:	accuracy=0.86667, loss=0.44771, regularization loss= 0.27111409337769815
# Validation accuracy: 0.80628, loss: 0.71593
# Iteration 800:	accuracy=0.96667, loss=0.33976, regularization loss= 0.27187835518897174
# Test accuracy=0.97710, loss=0.07361
# Validation accuracy: 0.80561, loss: 0.71915
# Iteration 900:	accuracy=0.93333, loss=0.18855, regularization loss= 0.27282455609920775
# Validation accuracy: 0.80694, loss: 0.70924
# Iteration 1000:	accuracy=0.93333, loss=0.13569, regularization loss= 0.2733374292564016
# Validation accuracy: 0.80872, loss: 0.69947
# Iteration 1100:	accuracy=0.93333, loss=0.28753, regularization loss= 0.27422074811512803
# Test accuracy=0.97690, loss=0.07417
# Validation accuracy: 0.80639, loss: 0.70233
# Iteration 1200:	accuracy=0.93333, loss=0.12768, regularization loss= 0.2750916809299189
# Validation accuracy: 0.80878, loss: 0.69800
# Iteration 1300:	accuracy=1.00000, loss=0.05509, regularization loss= 0.2755629152116446
# Validation accuracy: 0.80889, loss: 0.68956
# Iteration 1400:	accuracy=0.93333, loss=0.19810, regularization loss= 0.27662515031305146
# Test accuracy=0.97780, loss=0.07105
# Validation accuracy: 0.80700, loss: 0.69770
# Iteration 1500:	accuracy=0.96667, loss=0.17442, regularization loss= 0.2777468906111791
# Validation accuracy: 0.80894, loss: 0.70073
# Iteration 1600:	accuracy=0.93333, loss=0.39387, regularization loss= 0.27846737618555595
# Validation accuracy: 0.81228, loss: 0.68413
# Iteration 1700:	accuracy=0.90000, loss=0.24628, regularization loss= 0.2788839648561811
# Test accuracy=0.98020, loss=0.07110
# Validation accuracy: 0.81333, loss: 0.68365
# Iteration 1800:	accuracy=0.93333, loss=0.15278, regularization loss= 0.27926009906605137
# Validation accuracy: 0.81289, loss: 0.68071
# Iteration 1900:	accuracy=0.86667, loss=0.45116, regularization loss= 0.2797475301737515
# Validation accuracy: 0.81206, loss: 0.67325
# Iteration 2000:	accuracy=0.90000, loss=0.30593, regularization loss= 0.2801279981948336
# Test accuracy=0.97910, loss=0.07032
# Validation accuracy: 0.81333, loss: 0.67662
# Iteration 2100:	accuracy=1.00000, loss=0.03200, regularization loss= 0.28075252103629694
# Validation accuracy: 0.81067, loss: 0.67590
# Iteration 2200:	accuracy=0.96667, loss=0.16394, regularization loss= 0.28118089274694674
# Validation accuracy: 0.81217, loss: 0.67782
# Iteration 2300:	accuracy=0.90000, loss=0.37423, regularization loss= 0.2816670408802441
# Test accuracy=0.97960, loss=0.06904
# Validation accuracy: 0.81372, loss: 0.67734
# Iteration 2400:	accuracy=0.93333, loss=0.19476, regularization loss= 0.28210986642363267
# Validation accuracy: 0.81422, loss: 0.67378
# Iteration 2500:	accuracy=0.86667, loss=0.56129, regularization loss= 0.2826587815081262
# Validation accuracy: 0.81411, loss: 0.67748
# Iteration 2600:	accuracy=0.96667, loss=0.13353, regularization loss= 0.2831752386285973
# Test accuracy=0.98020, loss=0.06832
# Validation accuracy: 0.81456, loss: 0.67752
# Iteration 2700:	accuracy=0.93333, loss=0.15015, regularization loss= 0.2834862294633828
# Validation accuracy: 0.81250, loss: 0.67648
# Iteration 2800:	accuracy=0.83333, loss=0.52138, regularization loss= 0.28367481404868805
# Validation accuracy: 0.81322, loss: 0.67672
# Iteration 2900:	accuracy=0.93333, loss=0.19254, regularization loss= 0.2839553807509052
# Test accuracy=0.97910, loss=0.06953
# Validation accuracy: 0.81267, loss: 0.66998
# Iteration 3000:	accuracy=0.86667, loss=0.38521, regularization loss= 0.28426151600512223
# Validation accuracy: 0.81261, loss: 0.67887
# Iteration 3100:	accuracy=0.90000, loss=0.41012, regularization loss= 0.2845129469661974
# Validation accuracy: 0.81400, loss: 0.68021
# Iteration 3200:	accuracy=1.00000, loss=0.02326, regularization loss= 0.2847623295897002
# Test accuracy=0.97910, loss=0.06749
# Validation accuracy: 0.81261, loss: 0.68298
# Iteration 3300:	accuracy=0.96667, loss=0.21543, regularization loss= 0.2849815454126693
# Validation accuracy: 0.81283, loss: 0.68295
# Iteration 3400:	accuracy=0.80000, loss=0.63171, regularization loss= 0.2852092191152478
# Validation accuracy: 0.81261, loss: 0.68899
# Iteration 3500:	accuracy=0.96667, loss=0.33327, regularization loss= 0.2853657929090015
# Test accuracy=0.97960, loss=0.06717
# Validation accuracy: 0.81461, loss: 0.67560
# Iteration 3600:	accuracy=0.86667, loss=0.60321, regularization loss= 0.2856184591362077
# Validation accuracy: 0.81444, loss: 0.67928
# Iteration 3700:	accuracy=0.93333, loss=0.39264, regularization loss= 0.2857352516057558
# Validation accuracy: 0.81344, loss: 0.67822
# Iteration 3800:	accuracy=0.93333, loss=0.24789, regularization loss= 0.28587100263972415
# Test accuracy=0.97980, loss=0.06752
# Validation accuracy: 0.81461, loss: 0.67305
# Iteration 3900:	accuracy=0.96667, loss=0.13689, regularization loss= 0.28596162049832674
# Validation accuracy: 0.81400, loss: 0.67278
# Iteration 4000:	accuracy=0.96667, loss=0.07997, regularization loss= 0.28609120345850797
# Validation accuracy: 0.81489, loss: 0.67392
# Iteration 4100:	accuracy=0.96667, loss=0.15984, regularization loss= 0.2862428525533405
# Test accuracy=0.97980, loss=0.06765
# Validation accuracy: 0.81489, loss: 0.67145
# Iteration 4200:	accuracy=0.96667, loss=0.37325, regularization loss= 0.28635160758437783
# Validation accuracy: 0.81556, loss: 0.67246
# Iteration 4300:	accuracy=0.96667, loss=0.30364, regularization loss= 0.2864530598367841
# Validation accuracy: 0.81472, loss: 0.67165
# Iteration 4400:	accuracy=0.86667, loss=0.26715, regularization loss= 0.2865595431556307
# Test accuracy=0.97950, loss=0.06811
# Validation accuracy: 0.81544, loss: 0.66936
# Iteration 4500:	accuracy=0.93333, loss=0.14979, regularization loss= 0.28668208613427454
# Validation accuracy: 0.81433, loss: 0.67173
# Iteration 4600:	accuracy=0.96667, loss=0.14485, regularization loss= 0.2867492591504741
# Validation accuracy: 0.81428, loss: 0.66992
# Iteration 4700:	accuracy=0.93333, loss=0.14205, regularization loss= 0.28682006254816017
# Test accuracy=0.98000, loss=0.06797
# Validation accuracy: 0.81478, loss: 0.67095
# Iteration 4800:	accuracy=0.86667, loss=0.32010, regularization loss= 0.2868916664704969
# Validation accuracy: 0.81478, loss: 0.67279
# Iteration 4900:	accuracy=0.93333, loss=0.48125, regularization loss= 0.28698320390210474
# Validation accuracy: 0.81533, loss: 0.67216
# Iteration 5000:	accuracy=0.96667, loss=0.12296, regularization loss= 0.28702900253193414
# Test accuracy=0.97990, loss=0.06758
# Validation accuracy: 0.81572, loss: 0.67085
# Iteration 5100:	accuracy=0.86667, loss=0.63492, regularization loss= 0.2870933730654448
# Validation accuracy: 0.81517, loss: 0.67041
# Iteration 5200:	accuracy=0.93333, loss=0.19334, regularization loss= 0.28716327434507655
# Validation accuracy: 0.81483, loss: 0.66989
# Iteration 5300:	accuracy=0.96667, loss=0.16296, regularization loss= 0.287233280006199

# %%
plt.figure(2, figsize=(18, 8))
plt.subplot(2, 3, 1)
plt.title('Training loss')
plt.plot(train_results[:,0], train_results[:,1])
plt.subplot(2, 3, 4)
plt.title('Training accuracy')
plt.plot(train_results[:,0], train_results[:,2])
plt.subplot(2, 3, 2)
plt.title('Validation loss')
plt.plot(val_results[:,0], val_results[:,1])
plt.subplot(2, 3, 5)
plt.title('Validation accuracy')
plt.plot(val_results[:,0], val_results[:,2])
plt.subplot(2, 3, 3)
plt.title('Testing loss')
plt.plot(test_results[:,0], test_results[:, 1])
plt.subplot(2, 3, 6)
plt.title('Testing accuracy')
plt.plot(test_results[:, 0], test_results[:,2])

# %% [markdown]
# # Train your best MNISTNet!
# Tweak the hyperparameters of the above MNISTNet and use what you've learnt to train the best net.
#
# Credits will be given based on your test accuracy, your explanations/insights of the training. The network is small, hence the training should finish quickly using your CPU (less than 1 hour).
#
# Please report the following:
# - Training validation and testing loss as well as accuracy over iterations
# - Architecture and training method (eg. optimization scheme, data augmentation): explain your design choices, what has failed and what has worked and why you think they worked/failed
# - Try different hyper-parameters, e.g. rate decaying, weight decay, number of layers and total number of epochs.
#
# Do NOT use external libraries like Tensorflow, keras and Pytorch in your implementation, i.e. optimizer.py, layer.py and loss.py. Do NOT copy the code from the internet, e.g. github. You should also give credits to any material that you refer to for your implementation.

# %% [markdown]
# # Final submission instructions
# Please submit the following:
#
# 1) Your code files in a folder `codes`
#
# 2) A short report (1-2 pages) in pdf titled `report.pdf`, explaining the logic (expressed using mathematical formulation) of your implementation (including the forward and backward function like ReLU) and the findings from training your best net
#
# **ASSIGNMENT DEADLINE: 4 MAR 2018 (SUN) 17:00PM**
#
# Do not include the `data` folder as it takes up substantial memory. Please zip up the following folders under a folder named with your NUSNET ID: eg. `e0123456g.zip' and submit the zipped folder to IVLE/workbin/assignment 1 submission.
